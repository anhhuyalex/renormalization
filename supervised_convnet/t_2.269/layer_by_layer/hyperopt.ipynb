# %%
# !df -h
# !cat /proc/cpuinfo
# !cat /proc/meminfo
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         359G   30G  311G   9% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# tmpfs           6.4G   12K  6.4G   1% /var/colab
# /dev/sda1       365G   41G  325G  12% /opt/bin
# shm             5.9G  4.0K  5.9G   1% /dev/shm
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# MemTotal:       13335192 kB
# MemFree:        10709696 kB
# MemAvailable:   12509424 kB
# Buffers:           71580 kB
# Cached:          1886248 kB
# SwapCached:            0 kB
# Active:           674800 kB
# Inactive:        1680512 kB
# Active(anon):     377100 kB
# Inactive(anon):      328 kB
# Active(file):     297700 kB
# Inactive(file):  1680184 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               696 kB
# Writeback:             0 kB
# AnonPages:        397508 kB
# Mapped:           217080 kB
# Shmem:               892 kB
# Slab:             159252 kB
# SReclaimable:     125668 kB
# SUnreclaim:        33584 kB
# KernelStack:        3664 kB
# PageTables:         5436 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6667596 kB
# Committed_AS:    2808460 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# VmallocChunk:          0 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# DirectMap4k:       92148 kB
# DirectMap2M:     5150720 kB
# DirectMap1G:    10485760 kB

# %%
# !kill -9 -1
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
# gpu = GPUs[0]
# def printm():
#  process = psutil.Process(os.getpid())
#  print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
#  print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
# printm()



# !pip install -U --target=/usr/local/lib/python3.6/dist-packages git+https://github.com/pytorch/botorch.git

# !pip install -U -q torch==1.2.0 torchvision

# !pip install -U scikit-learn
# !pip install -U --target=/usr/local/lib/python3.6/dist-packages git+https://github.com/anhhuyalex/Ax.git
  
# !pip install -U --target=/usr/local/lib/python3.6/dist-packages git+https://github.com/anhhuyalex/Ax.git
  
  
# %cd /content
# %cd /usr/local/lib/python3.6/dist-packages
# !rm -rf botorch
# %cd /content
# !git clone https://github.com/pytorch/botorch.git
# %cd botorch
# !pip install .

# %cd /content
# %cd /usr/local/lib/python3.6/dist-packages
# !rm -rf gpytorch
# %cd /content
# !git clone https://github.com/cornellius-gp/gpytorch.git
# %cd gpytorch
# !pip install .

# !pip install sqlalchemy
# !pip install setproctitle
# !pip install ray[rllib]  # also recommended: ray[debug]
# !pip uninstall -y pyarrow
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/ed/0e/5c61eedde9f6c87713e89d794f01e378cfd9565847d4576fa627d758c554/GPUtil-1.4.0.tar.gz
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7410 sha256=99a803be2a62666f1da1cf1f793844289f897b307823c24f42c69aae17fb3759
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.4.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Collecting git+https://github.com/anhhuyalex/Ax.git
#   Cloning https://github.com/anhhuyalex/Ax.git to /tmp/pip-req-build-i_uvuf5i
#   Running command git clone -q https://github.com/anhhuyalex/Ax.git /tmp/pip-req-build-i_uvuf5i
# Collecting botorch>=0.1.3 (from ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/60/4a/eeec07acafa624c0657c9d70e2860f289f0d991da303bf07be618c770585/botorch-0.1.4-py3-none-any.whl (170kB)
#      |████████████████████████████████| 174kB 2.8MB/s
# Collecting jinja2 (from ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/65/e0/eb35e762802015cab1ccee04e8a277b03f1d8e53da3ec3106882ec42558b/Jinja2-2.10.3-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 47.7MB/s
# Collecting pandas (from ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/73/9b/52e228545d14f14bb2a1622e225f38463c8726645165e1cb7dde95bfe6d4/pandas-0.25.1-cp36-cp36m-manylinux1_x86_64.whl (10.5MB)
#      |████████████████████████████████| 10.5MB 49.1MB/s
# Collecting scipy (from ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/29/50/a552a5aff252ae915f522e44642bb49a7b7b31677f9580cfd11bcc869976/scipy-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (25.2MB)
#      |████████████████████████████████| 25.2MB 34.4MB/s
# Collecting sklearn (from ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Collecting plotly (from ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/70/19/8437e22c84083a6d5d8a3c80f4edc73c9dcbb89261d07e6bd13b48752bbd/plotly-4.1.1-py2.py3-none-any.whl (7.1MB)
#      |████████████████████████████████| 7.1MB 29.5MB/s
# Collecting gpytorch>=0.3.5 (from botorch>=0.1.3->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/a7/e4/e74dc12c6d07a5d8628dfb573b01297f7c2b44eec524be4b401c0782d39c/gpytorch-0.3.5.tar.gz (211kB)
#      |████████████████████████████████| 215kB 42.9MB/s
# Collecting torch>=1.2 (from botorch>=0.1.3->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/ae/05/50a05de5337f7a924bb8bd70c6936230642233e424d6a9747ef1cfbde353/torch-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (773.1MB)
#      |████████████████████████████████| 773.1MB 31kB/s
# Collecting MarkupSafe>=0.23 (from jinja2->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting numpy>=1.13.3 (from pandas->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/e5/e6/c3fdc53aed9fa19d6ff3abf97dfad768ae3afce1b7431f7500000816bda5/numpy-1.17.2-cp36-cp36m-manylinux1_x86_64.whl (20.4MB)
#      |████████████████████████████████| 20.4MB 28.5MB/s
# Collecting python-dateutil>=2.6.1 (from pandas->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl (226kB)
#      |████████████████████████████████| 235kB 41.4MB/s
# Collecting pytz>=2017.2 (from pandas->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl (509kB)
#      |████████████████████████████████| 512kB 42.0MB/s
# Collecting scikit-learn (from sklearn->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/a0/c5/d2238762d780dde84a20b8c761f563fe882b88c5a5fb03c056547c442a19/scikit_learn-0.21.3-cp36-cp36m-manylinux1_x86_64.whl (6.7MB)
#      |████████████████████████████████| 6.7MB 40.2MB/s
# Collecting retrying>=1.3.3 (from plotly->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Collecting six (from plotly->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting joblib>=0.11 (from scikit-learn->sklearn->ax-platform==0.1.4)
#   Downloading https://files.pythonhosted.org/packages/8f/42/155696f85f344c066e17af287359c9786b436b1bf86029bb3411283274f3/joblib-0.14.0-py2.py3-none-any.whl (294kB)
#      |████████████████████████████████| 296kB 34.2MB/s
# Building wheels for collected packages: ax-platform, sklearn, gpytorch, retrying
#   Building wheel for ax-platform (setup.py) ... done
#   Created wheel for ax-platform: filename=ax_platform-0.1.4-cp36-none-any.whl size=413805 sha256=36ce786426995c29a5815ff97a05297ac2920eedf90c83a1fcc0553ec5d1e3cf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-52lu6plz/wheels/cf/31/a7/531e4606a720574d740203ff00855672549f50a7d1b9bc736e
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=2984c6dde4fc202deabe80d8953116c1ab2e3f1909d13decdcc0456ece04c26d
#   Stored in directory: /root/.cache/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
#   Building wheel for gpytorch (setup.py) ... done
#   Created wheel for gpytorch: filename=gpytorch-0.3.5-py2.py3-none-any.whl size=349720 sha256=11b881f2944e859c118fab6e64c06787dd6c3a117b07e2b761e15a7d211f0548
#   Stored in directory: /root/.cache/pip/wheels/d6/31/88/c43a94e0073a54056ac663366f2195de36535b38a81a378196
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-cp36-none-any.whl size=11429 sha256=ce1de9d50ee8e3674feabb8ab7bee14d5336b263fadd77924060a6377900d470
#   Stored in directory: /root/.cache/pip/wheels/d7/a9/33/acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built ax-platform sklearn gpytorch retrying
# ERROR: torchvision 0.4.0 has requirement torch==1.2.0, but you'll have torch 1.3.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=0.24.0, but you'll have pandas 0.25.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy, scipy, gpytorch, torch, botorch, MarkupSafe, jinja2, six, python-dateutil, pytz, pandas, joblib, scikit-learn, sklearn, retrying, plotly, ax-platform
# Successfully installed MarkupSafe-1.1.1 ax-platform-0.1.4 botorch-0.1.4 gpytorch-0.3.5 jinja2-2.10.3 joblib-0.14.0 numpy-1.17.2 pandas-0.25.1 plotly-4.1.1 python-dateutil-2.8.0 pytz-2019.3 retrying-1.3.3 scikit-learn-0.21.3 scipy-1.3.1 six-1.12.0 sklearn-0.0 torch-1.3.0
# /content
# /content
# Cloning into 'botorch'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 6912 (delta 40), reused 76 (delta 22), pack-reused 6783
# Receiving objects: 100% (6912/6912), 11.13 MiB | 29.84 MiB/s, done.
# Resolving deltas: 100% (4396/4396), done.
# /content/botorch
# Processing /content/botorch
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.6/dist-packages (from botorch==0.1.4) (1.3.0)
# Requirement already satisfied: gpytorch>=0.3.5 in /usr/local/lib/python3.6/dist-packages (from botorch==0.1.4) (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from botorch==0.1.4) (1.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.3->botorch==0.1.4) (1.17.2)
# Building wheels for collected packages: botorch
#   Building wheel for botorch (setup.py) ... done
#   Created wheel for botorch: filename=botorch-0.1.4-cp36-none-any.whl size=180252 sha256=2086c5d412b319abc75b1a591f78a4272a33369a9abf5abdf5650958d60c85bd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dnm9an0p/wheels/d8/0e/3f/502176509633fec729eabc1a42e465b3603faf0c30b4782f33
# Successfully built botorch
# Installing collected packages: botorch
#   Found existing installation: botorch 0.1.4
#     Uninstalling botorch-0.1.4:
#       Successfully uninstalled botorch-0.1.4
# Successfully installed botorch-0.1.4
# /content
# /content
# Cloning into 'gpytorch'...
# remote: Enumerating objects: 224, done.
# remote: Counting objects: 100% (224/224), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 19565 (delta 140), reused 134 (delta 79), pack-reused 19341
# Receiving objects: 100% (19565/19565), 12.85 MiB | 19.53 MiB/s, done.
# Resolving deltas: 100% (14768/14768), done.
# /content/gpytorch
# Processing /content/gpytorch
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: gpytorch
#   Building wheel for gpytorch (PEP 517) ... done
#   Created wheel for gpytorch: filename=gpytorch-0.3.5-cp36-none-any.whl size=351905 sha256=62b4874fb17e30728f1bbd6d140305e5506cd7728a99b0d9cea6da2736c24775
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uv8getvd/wheels/2f/e4/e4/12ef9f1c6cbf687ede289b1fb10f20a814c3b6e4651095eb79
# Successfully built gpytorch
# Installing collected packages: gpytorch
#   Found existing installation: gpytorch 0.3.5
#     Uninstalling gpytorch-0.3.5:
#       Successfully uninstalled gpytorch-0.3.5
# Successfully installed gpytorch-0.3.5
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.6/dist-packages (1.3.9)
# Collecting setproctitle
#   Downloading https://files.pythonhosted.org/packages/5a/0d/dc0d2234aacba6cf1a729964383e3452c52096dc695581248b548786f2b3/setproctitle-1.1.10.tar.gz
# Building wheels for collected packages: setproctitle
#   Building wheel for setproctitle (setup.py) ... done
#   Created wheel for setproctitle: filename=setproctitle-1.1.10-cp36-cp36m-linux_x86_64.whl size=33921 sha256=e7cc80e7de8f860c146eb4ac3a9f18d724447b9fea25adbc8d33a6c8255a24e9
#   Stored in directory: /root/.cache/pip/wheels/e6/b1/a6/9719530228e258eba904501fef99d5d85c80d52bd8f14438a3
# Successfully built setproctitle
# Installing collected packages: setproctitle
# Successfully installed setproctitle-1.1.10
# Collecting ray[rllib]
#   Downloading https://files.pythonhosted.org/packages/9b/e7/37a7f8dc2b1f96c760a3950d8bb5a3f14066f1699f5d004f0f6462d880c9/ray-0.7.5-cp36-cp36m-manylinux1_x86_64.whl (74.9MB)
#      |████████████████████████████████| 74.9MB 24.9MB/s
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.6.4)
# Collecting protobuf>=3.8.0 (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/a8/52/d8d2dbff74b8bf517c42db8d44c3f9ef6555e6f5d6caddfa3f207b9143df/protobuf-3.10.0-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 32.4MB/s
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.17.2)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (7.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (2.6.0)
# Collecting funcsigs (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/69/cb/f5be453359271714c01b9bd06126eaf2e368f1fddfff30818754b5ac2328/funcsigs-1.0.2-py2.py3-none-any.whl
# Collecting redis>=3.3.2 (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/c2/61/8ab8a44e27d3d66af0186b6e1fa4a4965c16e2aad40f95a651989c26778d/redis-3.3.9-py2.py3-none-any.whl (66kB)
#      |████████████████████████████████| 71kB 24.2MB/s
# Collecting colorama (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/4f/a6/728666f39bfff1719fc94c481890b2106837da9318031f71a8424b662e12/colorama-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.0.12)
# Requirement already satisfied: six>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.12.0)
# Requirement already satisfied: gym[atari]; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.10.11)
# Collecting opencv-python-headless; extra == "rllib" (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/1f/dc/b250f03ab68068033fd2356428c1357431d8ebc6a26405098e0f27c94f7a/opencv_python_headless-4.1.1.26-cp36-cp36m-manylinux1_x86_64.whl (22.1MB)
#      |████████████████████████████████| 22.1MB 1.2MB/s
# Requirement already satisfied: scipy; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.3.1)
# Collecting lz4; extra == "rllib" (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/5d/5e/cedd32c203ce0303188b0c7ff8388bba3c33e4bf6da21ae789962c4fb2e7/lz4-2.2.1-cp36-cp36m-manylinux1_x86_64.whl (395kB)
#      |████████████████████████████████| 399kB 41.8MB/s
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (1.8.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (7.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (19.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (1.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (41.2.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (1.4.4)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (2.21.0)
# Requirement already satisfied: atari-py>=0.1.4; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (0.1.15)
# Requirement already satisfied: Pillow; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (4.3.0)
# Requirement already satisfied: PyOpenGL; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (3.1.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym[atari]; extra == "rllib"->ray[rllib]) (0.16.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]; extra == "rllib"->ray[rllib]) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]; extra == "rllib"->ray[rllib]) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]; extra == "rllib"->ray[rllib]) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]; extra == "rllib"->ray[rllib]) (2019.9.11)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow; extra == "atari"->gym[atari]; extra == "rllib"->ray[rllib]) (0.46)
# Installing collected packages: protobuf, funcsigs, redis, colorama, opencv-python-headless, lz4, ray
#   Found existing installation: protobuf 3.7.1
#     Uninstalling protobuf-3.7.1:
#       Successfully uninstalled protobuf-3.7.1
# Successfully installed colorama-0.4.1 funcsigs-1.0.2 lz4-2.2.1 opencv-python-headless-4.1.1.26 protobuf-3.10.0 ray-0.7.5 redis-3.3.9
# Uninstalling pyarrow-0.14.1:
#   Successfully uninstalled pyarrow-0.14.1

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Year\ 4\:\ Synthesis/NS162\:\ Statistical\ Mechanics/Renormalization\ Research\ Project/renormalization/supervised_convnet/t_2.269/layer_by_layer
import torch
import numpy as np
import pickle
import ray

from ax import RangeParameter, ParameterType
from ax.service.ax_client import AxClient
from ax.plot.contour import plot_contour
from ax.plot.trace import optimization_trace_single_method
from ax.service.managed_loop import optimize
from ax.utils.notebook.plotting import render, init_notebook_plotting

# import sys
import time
# sys.path.insert(0, "../../")
import supervised_convnet
import train#, frozen
# Out:
# /content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/layer_by_layer
# Uncorrelated [[ 0.32  0.54  0.37 -0.16  0.22  0.45 -0.19  0.22  0.28]
#  [ 0.23  0.23  0.51 -0.37 -0.14 -0.06  0.48  0.18  0.5 ]
#  [ 0.5   0.64  0.54 -0.56 -0.18 -0.06  0.39  0.42  0.51]
#  [ 0.57  0.03 -0.02 -0.55 -0.25 -0.17  0.55  0.05  0.41]
#  [ 0.38 -0.16  0.06 -0.36 -0.22 -0.44  0.31  0.53  0.6 ]
#  [ 0.03 -0.01  0.33 -0.41 -0.19 -0.35  0.56  0.4   0.56]
#  [-0.5  -0.47 -0.5   0.49  0.65  0.55  0.42  0.43 -0.43]
#  [-0.26 -0.57 -0.39  0.15  0.6   0.48  0.54  0.55 -0.21]
#  [-0.48 -0.58 -0.52  0.52  0.59 -0.22  0.33  0.2   0.46]]
# Correlated [[ 0.07  0.53  0.51  0.63  0.61  0.6   0.59  0.57  0.4 ]
#  [ 0.33  0.33  0.33  0.61  0.62  0.56  0.6   0.47  0.59]
#  [ 0.51  0.64  0.57  0.61  0.54  0.46  0.23  0.23  0.53]
#  [ 0.58  0.49  0.56  0.61  0.55  0.63  0.44 -0.1   0.54]
#  [ 0.57  0.54  0.62  0.58  0.51  0.57  0.47  0.08  0.12]
#  [ 0.57  0.57  0.63  0.52  0.45  0.49  0.63  0.24  0.38]
#  [ 0.6   0.46  0.47  0.55  0.58  0.58  0.59  0.55  0.64]
#  [ 0.6   0.64  0.55  0.59  0.63  0.63  0.62 -0.03  0.28]
#  [ 0.34  0.29  0.26  0.23  0.57  0.6   0.58  0.56  0.14]]

# %%
# Parameters
num_hidden_layers = 1
out_channels = 1
num_workers = 2
num_times = 1
run_mode = "unfrozen_convolution_relu9x9"
n_loops = 3000
save_loop = min(n_loops, 2)
use_cuda = True

# %%
# Start Ray.
ray.init()
#ray.init(num_gpus=1)

# GPU for use in colab
def model_to_cuda(model):
    if use_cuda and torch.cuda.is_available():
        model = model.cuda()
    return model

# @ray.remote(num_gpus = 1/num_workers)
@ray.remote
def init_model_and_train(hidden_size, batch_size, train_size, n_epochs, lr, weight_decay,
            betas0, betas1, seed, use_cuda):
    # Parameters
    num_hidden_layers = 1
    out_channels = 1


    if run_mode == "unfrozen_convolution_relu":
        model = supervised_convnet.SupervisedConvNet(filter_size = 3, square_size = 3, \
                hidden_size = hidden_size, out_channels = out_channels,
                first_activation = "tanh", activation_func = "relu",
                num_hidden_layers = num_hidden_layers, seed = seed)
        model = model_to_cuda(model)
        results = train.trainer(model = model, batch_size = batch_size, train_size = train_size, n_epochs = n_epochs, lr = lr,
                    weight_decay = weight_decay,
                    betas0 = 1-betas0, betas1 = 1-betas1, use_cuda = use_cuda)
    elif run_mode == "unfrozen_convolution_relu9x9":
        model = supervised_convnet.SupervisedConvNet(filter_size = 3, square_size = 3, \
                hidden_size = hidden_size, out_channels = out_channels,
                first_activation = "tanh", activation_func = "relu",
                num_hidden_layers = num_hidden_layers, seed = seed)
        model = model_to_cuda(model)
        results = train.trainer(model = model, batch_size = batch_size, train_size = train_size, n_epochs = n_epochs, lr = lr,
                    weight_decay = weight_decay,
                    betas0 = 1-betas0, betas1 = 1-betas1, use_cuda = use_cuda)
    elif run_mode == "frozen_convolution_no_center_relu":
        model = frozen.SupervisedConvNet(filter_size = 3, square_size = 3, \
                hidden_size = hidden_size, out_channels = out_channels,
                center = "omit", first_activation = "tanh",
                activation_func = "relu", num_hidden_layers = num_hidden_layers)
        model = model_to_cuda(model)
        results = train.trainer(model = model, batch_size = batch_size, train_size = train_size, n_epochs = n_epochs, lr = lr,
                    weight_decay = weight_decay,
                    betas0 = 1-betas0, betas1 = 1-betas1, use_cuda = use_cuda)
    elif run_mode == "frozen_convolution_pretrained_relu":
        model = frozen.SupervisedConvNet(filter_size = 3, square_size = 3, \
                hidden_size = hidden_size, out_channels = out_channels,
                center = "pre_trained", first_activation = "tanh",
                activation_func = "relu", num_hidden_layers = num_hidden_layers)
        model = model_to_cuda(model)
        results = train.trainer(model = model, batch_size = batch_size, train_size = train_size, n_epochs = n_epochs, lr = lr,
                    weight_decay = weight_decay,
                    betas0 = 1-betas0, betas1 = 1-betas1, use_cuda = use_cuda)
    elif run_mode == "unfrozen_convolution_2_channels":
        out_channels = 2
        model = supervised_convnet.SupervisedConvNet(filter_size = 3, square_size = 3,
                hidden_size = hidden_size, out_channels = out_channels,
                first_activation = "tanh", activation_func = "relu",
                num_hidden_layers = num_hidden_layers, seed = seed)
        model = model_to_cuda(model)
        results = train.trainer(model = model, batch_size = batch_size, train_size = train_size, n_epochs = n_epochs, lr = lr,
                    weight_decay = weight_decay,
                    betas0 = 1-betas0, betas1 = 1-betas1, use_cuda = use_cuda)
    return (results[0])



def train_evaluate(parameterization, use_cuda = use_cuda):
    # parameters
    batch_size = parameterization["batch_size"]
    train_size = parameterization["train_size"]
    n_epochs = parameterization["n_epochs"]
    lr = parameterization["lr"]
    weight_decay = parameterization["weight_decay"]
    betas0 = parameterization["betas0"]
    betas1 = parameterization["betas1"]
    hidden_size = 10
    use_cuda = use_cuda

    results = []
    # Start 4 tasks in parallel.
    for _ in range(num_times):
        result_ids = []
        for seed in range(num_workers):
            result_ids.append(init_model_and_train.remote(hidden_size, batch_size, train_size,
            n_epochs, lr, weight_decay, betas0, betas1,
            time.time() + seed, use_cuda))

        # Wait for the tasks to complete and retrieve the results.
        # With at least 4 cores, this will take 1 second.
        results.append(ray.get(result_ids))  # [0, 1, 2, 3]

    # results = []
    # for seed in range(num_workers):
    #     results.append(init_model_and_train(hidden_size, batch_size, train_size,
    #     n_epochs, lr, weight_decay, betas0, betas1,
    #     time.time() + seed))

    print ("results", results)
    mean = np.mean(results)
    SEM = np.std(results)/np.sqrt(len(results))
    # pool.close() # no more tasks
    # pool.join()  # wrap up current tasks
    return {"objective": (mean, SEM)}
# Out:
# 2019-10-10 23:21:21,201	INFO resource_spec.py:205 -- Starting Ray with 4.49 GiB memory available for workers and up to 2.25 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).

# %%
# %%capture
# Initialize client
ax_client = AxClient()
try:
    with open(f"/content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/layer_by_layer/colab/hyperparameters_{run_mode}.pl", "rb") as handle:
        hyper = pickle.load(handle)
    v = hyper["axclient"].copy()
    ax_client = ax_client.from_json_snapshot(v)
except:
    ax_client.create_experiment(
        parameters=[
            {
              "name": "batch_size",
              "type": "range",
              "bounds": [1, 5000],
              "value_type": "int"
            },
            {
              "name": "train_size",
              "type": "range",
              "bounds": [100, 5000],
              "value_type": "int"
            },
            {
              "name": "n_epochs",
              "type": "range",
              "bounds": [50, 250],
              "value_type": "int"
            },
            {
              "name": "lr",
              "type": "range",
              "bounds": [1e-4, 1],
              "value_type": "float",
              "log_scale": True
            },
            {
              "name": "weight_decay",
              "type": "range",
              "bounds": [1e-5, 2e-1],
              "value_type": "float",
              "log_scale": True
            },
            {
              "name": "betas0",
              "type": "range",
              "bounds": [1e-5, 2e-1],
              "value_type": "float",
              "log_scale": True
            },
            {
              "name": "betas1",
              "type": "range",
              "bounds": [1e-5, 2e-1],
              "value_type": "float",
              "log_scale": True
            }
        ],
        parameter_constraints=["0.02 * train_size + -1 * batch_size <= 0", "train_size >= batch_size"],
        minimize=False,
        objective_name="objective",
        outcome_constraints=None,
        name="Test"
    )

# print ("axclient",ax_client.experiment.trials )
# for loop in range(n_loops):
for loop in range(n_loops):
    print(f"Running trial {loop}/{n_loops}...")
    parameters, trial_index = ax_client.get_next_trial()
    print("trial_index", trial_index)
#     time.sleep(2)
    # parameters["n_epochs"] = 5
     # Local evaluation here can be replaced with deployment to external system.
    ax_client.complete_trial(trial_index=trial_index, raw_data=train_evaluate(parameters))
    print("Best params", ax_client.get_best_parameters())
    # periodic save
    if loop % save_loop == (save_loop - 1):
        optim_result = ax_client.get_best_parameters()
        # print("best_parameters", optim_result)
        # print("was I saved?", ax._save_experiment_and_generation_strategy_if_possible())
        hyper = {}
        hyper["best_params"] = optim_result
        hyper["axclient"] = ax_client.to_json_snapshot()
        # print("optim_result", optim_result)
        with open(f"/content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/layer_by_layer/colab/hyperparameters_{run_mode}.pl", "wb") as handle:
            pickle.dump(hyper, handle, protocol = pickle.HIGHEST_PROTOCOL)
# Out:
# [INFO 10-10 23:21:23] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 2 decimal points.
# [INFO 10-10 23:21:23] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 2 decimal points.
# [INFO 10-10 23:21:23] ax.service.ax_client: Generated new trial 2 with parameters {'batch_size': 1829, 'train_size': 3097, 'n_epochs': 117, 'lr': 0.09, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:21:39] ax.service.ax_client: Completed trial 2 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-10 23:21:39] ax.service.ax_client: Generated new trial 3 with parameters {'batch_size': 3371, 'train_size': 3805, 'n_epochs': 156, 'lr': 0.23, 'weight_decay': 0.0, 'betas0': 0.02, 'betas1': 0.0}.
# [INFO 10-10 23:21:54] ax.service.ax_client: Completed trial 3 with data: {'objective': (0.85, 0.01)}.
# [INFO 10-10 23:21:54] ax.service.ax_client: Generated new trial 4 with parameters {'batch_size': 1141, 'train_size': 3568, 'n_epochs': 200, 'lr': 0.0, 'weight_decay': 0.0, 'betas0': 0.0, 'betas1': 0.01}.
# [INFO 10-10 23:22:10] ax.service.ax_client: Completed trial 4 with data: {'objective': (0.66, 0.1)}.
# [INFO 10-10 23:22:10] ax.service.ax_client: Generated new trial 5 with parameters {'batch_size': 3973, 'train_size': 4545, 'n_epochs': 136, 'lr': 0.0, 'weight_decay': 0.04, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:22:24] ax.service.ax_client: Completed trial 5 with data: {'objective': (0.5, 0.0)}.
# [INFO 10-10 23:22:24] ax.service.ax_client: Generated new trial 6 with parameters {'batch_size': 2044, 'train_size': 4311, 'n_epochs': 68, 'lr': 0.01, 'weight_decay': 0.08, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:22:30] ax.service.ax_client: Completed trial 6 with data: {'objective': (0.5, 0.0)}.
# [INFO 10-10 23:22:32] ax.service.ax_client: Generated new trial 7 with parameters {'batch_size': 2677, 'train_size': 3290, 'n_epochs': 139, 'lr': 0.16, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:22:42] ax.service.ax_client: Completed trial 7 with data: {'objective': (0.86, 0.0)}.
# [INFO 10-10 23:22:44] ax.service.ax_client: Generated new trial 8 with parameters {'batch_size': 1849, 'train_size': 2839, 'n_epochs': 161, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:22:54] ax.service.ax_client: Completed trial 8 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:22:57] ax.service.ax_client: Generated new trial 9 with parameters {'batch_size': 1698, 'train_size': 3410, 'n_epochs': 138, 'lr': 0.17, 'weight_decay': 0.0, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:23:07] ax.service.ax_client: Completed trial 9 with data: {'objective': (0.76, 0.0)}.
# [INFO 10-10 23:23:09] ax.service.ax_client: Generated new trial 10 with parameters {'batch_size': 2519, 'train_size': 2653, 'n_epochs': 160, 'lr': 0.03, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:23:19] ax.service.ax_client: Completed trial 10 with data: {'objective': (0.83, 0.02)}.
# [INFO 10-10 23:23:22] ax.service.ax_client: Generated new trial 11 with parameters {'batch_size': 1680, 'train_size': 2687, 'n_epochs': 136, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:23:30] ax.service.ax_client: Completed trial 11 with data: {'objective': (0.81, 0.02)}.
# [INFO 10-10 23:23:32] ax.service.ax_client: Generated new trial 12 with parameters {'batch_size': 3122, 'train_size': 3122, 'n_epochs': 183, 'lr': 0.07, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:23:45] ax.service.ax_client: Completed trial 12 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:23:49] ax.service.ax_client: Generated new trial 13 with parameters {'batch_size': 3195, 'train_size': 3195, 'n_epochs': 145, 'lr': 0.07, 'weight_decay': 0.0, 'betas0': 0.06, 'betas1': 0.0}.
# [INFO 10-10 23:23:59] ax.service.ax_client: Completed trial 13 with data: {'objective': (0.85, 0.01)}.
# [INFO 10-10 23:24:03] ax.service.ax_client: Generated new trial 14 with parameters {'batch_size': 3504, 'train_size': 3504, 'n_epochs': 184, 'lr': 0.13, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:24:17] ax.service.ax_client: Completed trial 14 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:24:21] ax.service.ax_client: Generated new trial 15 with parameters {'batch_size': 3110, 'train_size': 3110, 'n_epochs': 153, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:24:32] ax.service.ax_client: Completed trial 15 with data: {'objective': (0.86, 0.0)}.
# [INFO 10-10 23:24:37] ax.service.ax_client: Generated new trial 16 with parameters {'batch_size': 2453, 'train_size': 3403, 'n_epochs': 192, 'lr': 0.03, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:24:51] ax.service.ax_client: Completed trial 16 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:24:56] ax.service.ax_client: Generated new trial 17 with parameters {'batch_size': 3638, 'train_size': 3817, 'n_epochs': 176, 'lr': 0.1, 'weight_decay': 0.0, 'betas0': 0.02, 'betas1': 0.0}.
# [INFO 10-10 23:25:10] ax.service.ax_client: Completed trial 17 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-10 23:25:13] ax.service.ax_client: Generated new trial 18 with parameters {'batch_size': 2345, 'train_size': 2818, 'n_epochs': 215, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:25:26] ax.service.ax_client: Completed trial 18 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:25:30] ax.service.ax_client: Generated new trial 19 with parameters {'batch_size': 2013, 'train_size': 2671, 'n_epochs': 208, 'lr': 0.01, 'weight_decay': 0.0, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:25:42] ax.service.ax_client: Completed trial 19 with data: {'objective': (0.83, 0.02)}.
# [INFO 10-10 23:25:48] ax.service.ax_client: Generated new trial 20 with parameters {'batch_size': 2647, 'train_size': 3146, 'n_epochs': 187, 'lr': 0.08, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:26:01] ax.service.ax_client: Completed trial 20 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-10 23:26:06] ax.service.ax_client: Generated new trial 21 with parameters {'batch_size': 1919, 'train_size': 3187, 'n_epochs': 191, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:26:20] ax.service.ax_client: Completed trial 21 with data: {'objective': (0.83, 0.03)}.
# [INFO 10-10 23:26:24] ax.service.ax_client: Generated new trial 22 with parameters {'batch_size': 3475, 'train_size': 3475, 'n_epochs': 236, 'lr': 0.09, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:26:40] ax.service.ax_client: Completed trial 22 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:26:46] ax.service.ax_client: Generated new trial 23 with parameters {'batch_size': 3127, 'train_size': 3127, 'n_epochs': 222, 'lr': 0.1, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:27:00] ax.service.ax_client: Completed trial 23 with data: {'objective': (0.82, 0.03)}.
# [INFO 10-10 23:27:06] ax.service.ax_client: Generated new trial 24 with parameters {'batch_size': 3515, 'train_size': 3564, 'n_epochs': 188, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.02, 'betas1': 0.0}.
# [INFO 10-10 23:27:21] ax.service.ax_client: Completed trial 24 with data: {'objective': (0.8, 0.02)}.
# [INFO 10-10 23:27:27] ax.service.ax_client: Generated new trial 25 with parameters {'batch_size': 3404, 'train_size': 3404, 'n_epochs': 219, 'lr': 0.22, 'weight_decay': 0.0, 'betas0': 0.03, 'betas1': 0.0}.
# [INFO 10-10 23:27:44] ax.service.ax_client: Completed trial 25 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:27:50] ax.service.ax_client: Generated new trial 26 with parameters {'batch_size': 2356, 'train_size': 3072, 'n_epochs': 150, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:28:01] ax.service.ax_client: Completed trial 26 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:28:07] ax.service.ax_client: Generated new trial 27 with parameters {'batch_size': 3333, 'train_size': 3333, 'n_epochs': 189, 'lr': 0.16, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:28:21] ax.service.ax_client: Completed trial 27 with data: {'objective': (0.86, 0.02)}.
# [INFO 10-10 23:28:27] ax.service.ax_client: Generated new trial 28 with parameters {'batch_size': 3680, 'train_size': 3680, 'n_epochs': 141, 'lr': 0.32, 'weight_decay': 0.0, 'betas0': 0.08, 'betas1': 0.0}.
# [INFO 10-10 23:28:38] ax.service.ax_client: Completed trial 28 with data: {'objective': (0.84, 0.02)}.
# [INFO 10-10 23:28:44] ax.service.ax_client: Generated new trial 29 with parameters {'batch_size': 2958, 'train_size': 2958, 'n_epochs': 250, 'lr': 0.08, 'weight_decay': 0.0, 'betas0': 0.03, 'betas1': 0.0}.
# [INFO 10-10 23:29:00] ax.service.ax_client: Completed trial 29 with data: {'objective': (0.86, 0.02)}.
# [INFO 10-10 23:29:05] ax.service.ax_client: Generated new trial 30 with parameters {'batch_size': 3995, 'train_size': 3995, 'n_epochs': 250, 'lr': 0.3, 'weight_decay': 0.0, 'betas0': 0.02, 'betas1': 0.0}.
# [INFO 10-10 23:29:27] ax.service.ax_client: Completed trial 30 with data: {'objective': (0.69, 0.19)}.
# [INFO 10-10 23:29:33] ax.service.ax_client: Generated new trial 31 with parameters {'batch_size': 1393, 'train_size': 3108, 'n_epochs': 194, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.03, 'betas1': 0.0}.
# [INFO 10-10 23:29:45] ax.service.ax_client: Completed trial 31 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:29:51] ax.service.ax_client: Generated new trial 32 with parameters {'batch_size': 2109, 'train_size': 3807, 'n_epochs': 145, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.05, 'betas1': 0.0}.
# [INFO 10-10 23:30:02] ax.service.ax_client: Completed trial 32 with data: {'objective': (0.89, 0.0)}.
# [INFO 10-10 23:30:08] ax.service.ax_client: Generated new trial 33 with parameters {'batch_size': 1715, 'train_size': 3673, 'n_epochs': 124, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.02, 'betas1': 0.0}.
# [INFO 10-10 23:30:17] ax.service.ax_client: Completed trial 33 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:30:23] ax.service.ax_client: Generated new trial 34 with parameters {'batch_size': 2404, 'train_size': 3754, 'n_epochs': 197, 'lr': 0.08, 'weight_decay': 0.0, 'betas0': 0.12, 'betas1': 0.0}.
# [INFO 10-10 23:30:38] ax.service.ax_client: Completed trial 34 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:30:43] ax.service.ax_client: Generated new trial 35 with parameters {'batch_size': 2012, 'train_size': 3188, 'n_epochs': 134, 'lr': 0.09, 'weight_decay': 0.0, 'betas0': 0.14, 'betas1': 0.0}.
# [INFO 10-10 23:30:52] ax.service.ax_client: Completed trial 35 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:30:57] ax.service.ax_client: Generated new trial 36 with parameters {'batch_size': 2744, 'train_size': 4046, 'n_epochs': 147, 'lr': 0.1, 'weight_decay': 0.0, 'betas0': 0.05, 'betas1': 0.0}.
# [INFO 10-10 23:31:09] ax.service.ax_client: Completed trial 36 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:31:16] ax.service.ax_client: Generated new trial 37 with parameters {'batch_size': 2213, 'train_size': 3544, 'n_epochs': 168, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.03, 'betas1': 0.0}.
# [INFO 10-10 23:31:29] ax.service.ax_client: Completed trial 37 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:31:34] ax.service.ax_client: Generated new trial 38 with parameters {'batch_size': 1657, 'train_size': 4457, 'n_epochs': 168, 'lr': 0.09, 'weight_decay': 0.0, 'betas0': 0.14, 'betas1': 0.0}.
# [INFO 10-10 23:31:49] ax.service.ax_client: Completed trial 38 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:31:54] ax.service.ax_client: Generated new trial 39 with parameters {'batch_size': 2360, 'train_size': 4472, 'n_epochs': 108, 'lr': 0.12, 'weight_decay': 0.0, 'betas0': 0.09, 'betas1': 0.0}.
# [INFO 10-10 23:32:04] ax.service.ax_client: Completed trial 39 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:32:09] ax.service.ax_client: Generated new trial 40 with parameters {'batch_size': 2240, 'train_size': 4840, 'n_epochs': 146, 'lr': 0.07, 'weight_decay': 0.0, 'betas0': 0.18, 'betas1': 0.0}.
# [INFO 10-10 23:32:24] ax.service.ax_client: Completed trial 40 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:32:30] ax.service.ax_client: Generated new trial 41 with parameters {'batch_size': 2216, 'train_size': 4536, 'n_epochs': 159, 'lr': 0.09, 'weight_decay': 0.0, 'betas0': 0.03, 'betas1': 0.0}.
# [INFO 10-10 23:32:47] ax.service.ax_client: Completed trial 41 with data: {'objective': (0.85, 0.01)}.
# [INFO 10-10 23:32:55] ax.service.ax_client: Generated new trial 42 with parameters {'batch_size': 2324, 'train_size': 4259, 'n_epochs': 110, 'lr': 0.07, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:33:06] ax.service.ax_client: Completed trial 42 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:33:06] ModelBridge: Leaving out out-of-design observations for arms: 42_0
# [INFO 10-10 23:33:14] ax.service.ax_client: Generated new trial 43 with parameters {'batch_size': 2322, 'train_size': 4260, 'n_epochs': 108, 'lr': 0.07, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:33:23] ax.service.ax_client: Completed trial 43 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:33:23] ModelBridge: Leaving out out-of-design observations for arms: 42_0
# [INFO 10-10 23:33:31] ax.service.ax_client: Generated new trial 44 with parameters {'batch_size': 2210, 'train_size': 4218, 'n_epochs': 123, 'lr': 0.11, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:33:42] ax.service.ax_client: Completed trial 44 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-10 23:33:42] ModelBridge: Leaving out out-of-design observations for arms: 42_0, 44_0
# [INFO 10-10 23:33:48] ax.service.ax_client: Generated new trial 45 with parameters {'batch_size': 2222, 'train_size': 4215, 'n_epochs': 125, 'lr': 0.11, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:33:59] ax.service.ax_client: Completed trial 45 with data: {'objective': (0.86, 0.0)}.
# [INFO 10-10 23:34:00] ModelBridge: Leaving out out-of-design observations for arms: 45_0, 42_0, 44_0
# [INFO 10-10 23:34:07] ax.service.ax_client: Generated new trial 46 with parameters {'batch_size': 2202, 'train_size': 4209, 'n_epochs': 122, 'lr': 0.11, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:34:18] ax.service.ax_client: Completed trial 46 with data: {'objective': (0.86, 0.0)}.
# [INFO 10-10 23:34:18] ModelBridge: Leaving out out-of-design observations for arms: 45_0, 46_0, 42_0, 44_0
# [INFO 10-10 23:34:25] ax.service.ax_client: Generated new trial 47 with parameters {'batch_size': 2222, 'train_size': 4221, 'n_epochs': 122, 'lr': 0.11, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:34:36] ax.service.ax_client: Completed trial 47 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:34:37] ModelBridge: Leaving out out-of-design observations for arms: 46_0, 42_0, 45_0, 47_0, 44_0
# [INFO 10-10 23:34:44] ax.service.ax_client: Generated new trial 48 with parameters {'batch_size': 2213, 'train_size': 4216, 'n_epochs': 122, 'lr': 0.11, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:34:56] ax.service.ax_client: Completed trial 48 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-10 23:34:56] ModelBridge: Leaving out out-of-design observations for arms: 46_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:35:03] ax.service.ax_client: Generated new trial 49 with parameters {'batch_size': 2205, 'train_size': 4229, 'n_epochs': 122, 'lr': 0.11, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:35:14] ax.service.ax_client: Completed trial 49 with data: {'objective': (0.85, 0.01)}.
# [INFO 10-10 23:35:14] ModelBridge: Leaving out out-of-design observations for arms: 46_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:35:21] ax.service.ax_client: Generated new trial 50 with parameters {'batch_size': 2196, 'train_size': 4234, 'n_epochs': 122, 'lr': 0.11, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:35:33] ax.service.ax_client: Completed trial 50 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:35:33] ModelBridge: Leaving out out-of-design observations for arms: 46_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:35:40] ax.service.ax_client: Generated new trial 51 with parameters {'batch_size': 2212, 'train_size': 4220, 'n_epochs': 123, 'lr': 0.11, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:35:51] ax.service.ax_client: Completed trial 51 with data: {'objective': (0.86, 0.02)}.
# [INFO 10-10 23:35:51] ModelBridge: Leaving out out-of-design observations for arms: 46_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:35:58] ax.service.ax_client: Generated new trial 52 with parameters {'batch_size': 1918, 'train_size': 4321, 'n_epochs': 183, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:36:16] ax.service.ax_client: Completed trial 52 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:36:16] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 46_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:36:23] ax.service.ax_client: Generated new trial 53 with parameters {'batch_size': 1920, 'train_size': 4309, 'n_epochs': 183, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:36:41] ax.service.ax_client: Completed trial 53 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:36:41] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:36:48] ax.service.ax_client: Generated new trial 54 with parameters {'batch_size': 1914, 'train_size': 4318, 'n_epochs': 183, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:37:06] ax.service.ax_client: Completed trial 54 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:37:06] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:37:13] ax.service.ax_client: Generated new trial 55 with parameters {'batch_size': 1932, 'train_size': 4312, 'n_epochs': 183, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:37:31] ax.service.ax_client: Completed trial 55 with data: {'objective': (0.81, 0.07)}.
# [INFO 10-10 23:37:31] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:37:38] ax.service.ax_client: Generated new trial 56 with parameters {'batch_size': 2017, 'train_size': 4175, 'n_epochs': 202, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.14, 'betas1': 0.0}.
# [INFO 10-10 23:37:57] ax.service.ax_client: Completed trial 56 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:37:57] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:38:03] ax.service.ax_client: Generated new trial 57 with parameters {'batch_size': 2122, 'train_size': 2960, 'n_epochs': 191, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:38:16] ax.service.ax_client: Completed trial 57 with data: {'objective': (0.86, 0.02)}.
# [INFO 10-10 23:38:16] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:38:22] ax.service.ax_client: Generated new trial 58 with parameters {'batch_size': 4065, 'train_size': 4065, 'n_epochs': 250, 'lr': 0.24, 'weight_decay': 0.0, 'betas0': 0.08, 'betas1': 0.0}.
# [INFO 10-10 23:38:46] ax.service.ax_client: Completed trial 58 with data: {'objective': (0.66, 0.16)}.
# [INFO 10-10 23:38:46] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:38:53] ax.service.ax_client: Generated new trial 59 with parameters {'batch_size': 3191, 'train_size': 3193, 'n_epochs': 50, 'lr': 0.15, 'weight_decay': 0.0, 'betas0': 0.03, 'betas1': 0.0}.
# [INFO 10-10 23:38:56] ax.service.ax_client: Completed trial 59 with data: {'objective': (0.55, 0.06)}.
# [INFO 10-10 23:38:57] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:39:05] ax.service.ax_client: Generated new trial 60 with parameters {'batch_size': 1404, 'train_size': 3664, 'n_epochs': 153, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.12, 'betas1': 0.02}.
# [INFO 10-10 23:39:18] ax.service.ax_client: Completed trial 60 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:39:18] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:39:24] ax.service.ax_client: Generated new trial 61 with parameters {'batch_size': 1342, 'train_size': 4775, 'n_epochs': 113, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:39:36] ax.service.ax_client: Completed trial 61 with data: {'objective': (0.86, 0.02)}.
# [INFO 10-10 23:39:36] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 44_0
# [INFO 10-10 23:39:44] ax.service.ax_client: Generated new trial 62 with parameters {'batch_size': 2048, 'train_size': 3961, 'n_epochs': 159, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:39:58] ax.service.ax_client: Completed trial 62 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:39:58] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:40:06] ax.service.ax_client: Generated new trial 63 with parameters {'batch_size': 2030, 'train_size': 3963, 'n_epochs': 159, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:40:20] ax.service.ax_client: Completed trial 63 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:40:20] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 63_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:40:30] ax.service.ax_client: Generated new trial 64 with parameters {'batch_size': 2030, 'train_size': 3962, 'n_epochs': 160, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:40:44] ax.service.ax_client: Completed trial 64 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:40:44] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 63_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:40:51] ax.service.ax_client: Generated new trial 65 with parameters {'batch_size': 3168, 'train_size': 3168, 'n_epochs': 250, 'lr': 0.16, 'weight_decay': 0.0, 'betas0': 0.03, 'betas1': 0.0}.
# [INFO 10-10 23:41:09] ax.service.ax_client: Completed trial 65 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:41:09] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 63_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:41:17] ax.service.ax_client: Generated new trial 66 with parameters {'batch_size': 3036, 'train_size': 3036, 'n_epochs': 250, 'lr': 0.18, 'weight_decay': 0.0, 'betas0': 0.0, 'betas1': 0.0}.
# [INFO 10-10 23:41:34] ax.service.ax_client: Completed trial 66 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-10 23:41:34] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 50_0, 49_0, 42_0, 45_0, 63_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:41:43] ax.service.ax_client: Generated new trial 67 with parameters {'batch_size': 3168, 'train_size': 3942, 'n_epochs': 230, 'lr': 0.13, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:42:05] ax.service.ax_client: Completed trial 67 with data: {'objective': (0.85, 0.02)}.
# [INFO 10-10 23:42:05] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 67_0, 50_0, 49_0, 42_0, 45_0, 63_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:42:14] ax.service.ax_client: Generated new trial 68 with parameters {'batch_size': 3177, 'train_size': 4002, 'n_epochs': 232, 'lr': 0.14, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:42:36] ax.service.ax_client: Completed trial 68 with data: {'objective': (0.82, 0.06)}.
# [INFO 10-10 23:42:36] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 67_0, 50_0, 49_0, 42_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:42:43] ax.service.ax_client: Generated new trial 69 with parameters {'batch_size': 3188, 'train_size': 4125, 'n_epochs': 239, 'lr': 0.14, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:43:06] ax.service.ax_client: Completed trial 69 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:43:07] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:43:14] ax.service.ax_client: Generated new trial 70 with parameters {'batch_size': 3172, 'train_size': 4072, 'n_epochs': 237, 'lr': 0.14, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:43:37] ax.service.ax_client: Completed trial 70 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:43:37] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:43:45] ax.service.ax_client: Generated new trial 71 with parameters {'batch_size': 3159, 'train_size': 3899, 'n_epochs': 229, 'lr': 0.13, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:44:06] ax.service.ax_client: Completed trial 71 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:44:06] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 71_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:44:14] ax.service.ax_client: Generated new trial 72 with parameters {'batch_size': 3159, 'train_size': 3901, 'n_epochs': 230, 'lr': 0.13, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:44:36] ax.service.ax_client: Completed trial 72 with data: {'objective': (0.85, 0.01)}.
# [INFO 10-10 23:44:36] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 71_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:44:43] ax.service.ax_client: Generated new trial 73 with parameters {'batch_size': 1316, 'train_size': 2479, 'n_epochs': 176, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.05}.
# [INFO 10-10 23:44:52] ax.service.ax_client: Completed trial 73 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-10 23:44:53] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 71_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:45:00] ax.service.ax_client: Generated new trial 74 with parameters {'batch_size': 2994, 'train_size': 2994, 'n_epochs': 250, 'lr': 0.07, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.01}.
# [INFO 10-10 23:45:16] ax.service.ax_client: Completed trial 74 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:45:16] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 71_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:45:24] ax.service.ax_client: Generated new trial 75 with parameters {'batch_size': 3714, 'train_size': 3714, 'n_epochs': 228, 'lr': 0.37, 'weight_decay': 0.0, 'betas0': 0.01, 'betas1': 0.0}.
# [INFO 10-10 23:45:43] ax.service.ax_client: Completed trial 75 with data: {'objective': (0.86, 0.0)}.
# [INFO 10-10 23:45:43] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 71_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:45:50] ax.service.ax_client: Generated new trial 76 with parameters {'batch_size': 1896, 'train_size': 3306, 'n_epochs': 171, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.04, 'betas1': 0.01}.
# [INFO 10-10 23:46:02] ax.service.ax_client: Completed trial 76 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:46:02] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 71_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:46:09] ax.service.ax_client: Generated new trial 77 with parameters {'batch_size': 2918, 'train_size': 2918, 'n_epochs': 198, 'lr': 0.1, 'weight_decay': 0.0, 'betas0': 0.03, 'betas1': 0.0}.
# [INFO 10-10 23:46:22] ax.service.ax_client: Completed trial 77 with data: {'objective': (0.87, 0.02)}.
# [INFO 10-10 23:46:22] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 71_0, 45_0, 63_0, 68_0, 48_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:46:30] ax.service.ax_client: Generated new trial 78 with parameters {'batch_size': 2021, 'train_size': 5000, 'n_epochs': 142, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:46:44] ax.service.ax_client: Completed trial 78 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:46:44] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 71_0, 45_0, 63_0, 68_0, 48_0, 78_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:46:51] ax.service.ax_client: Generated new trial 79 with parameters {'batch_size': 2001, 'train_size': 4985, 'n_epochs': 140, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:47:05] ax.service.ax_client: Completed trial 79 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:47:05] ModelBridge: Leaving out out-of-design observations for arms: 52_0, 54_0, 70_0, 46_0, 53_0, 67_0, 69_0, 50_0, 49_0, 42_0, 71_0, 45_0, 63_0, 68_0, 48_0, 79_0, 78_0, 47_0, 62_0, 44_0
# [INFO 10-10 23:47:12] ax.service.ax_client: Generated new trial 80 with parameters {'batch_size': 2031, 'train_size': 4947, 'n_epochs': 142, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:47:27] ax.service.ax_client: Completed trial 80 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:47:27] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 62_0, 44_0, 52_0, 46_0, 69_0, 71_0, 42_0, 80_0, 68_0, 78_0, 54_0, 53_0, 67_0, 49_0, 63_0, 47_0
# [INFO 10-10 23:47:34] ax.service.ax_client: Generated new trial 81 with parameters {'batch_size': 2009, 'train_size': 4961, 'n_epochs': 142, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:47:48] ax.service.ax_client: Completed trial 81 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:47:48] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 62_0, 44_0, 52_0, 46_0, 69_0, 71_0, 42_0, 80_0, 68_0, 78_0, 54_0, 53_0, 67_0, 49_0, 63_0, 81_0, 47_0
# [INFO 10-10 23:47:56] ax.service.ax_client: Generated new trial 82 with parameters {'batch_size': 2004, 'train_size': 4909, 'n_epochs': 142, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:48:10] ax.service.ax_client: Completed trial 82 with data: {'objective': (0.85, 0.01)}.
# [INFO 10-10 23:48:10] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 62_0, 44_0, 52_0, 46_0, 69_0, 71_0, 42_0, 80_0, 68_0, 78_0, 54_0, 53_0, 67_0, 82_0, 49_0, 63_0, 81_0, 47_0
# [INFO 10-10 23:48:17] ax.service.ax_client: Generated new trial 83 with parameters {'batch_size': 2444, 'train_size': 4311, 'n_epochs': 143, 'lr': 0.07, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:48:29] ax.service.ax_client: Completed trial 83 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:48:29] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 62_0, 44_0, 52_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 54_0, 53_0, 67_0, 82_0, 49_0, 63_0, 81_0, 47_0
# [INFO 10-10 23:48:36] ax.service.ax_client: Generated new trial 84 with parameters {'batch_size': 2018, 'train_size': 5000, 'n_epochs': 142, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:48:51] ax.service.ax_client: Completed trial 84 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:48:51] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 84_0, 62_0, 44_0, 52_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 54_0, 53_0, 67_0, 82_0, 49_0, 63_0, 81_0, 47_0
# [INFO 10-10 23:48:58] ax.service.ax_client: Generated new trial 85 with parameters {'batch_size': 2027, 'train_size': 4961, 'n_epochs': 142, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:49:12] ax.service.ax_client: Completed trial 85 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:49:12] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 84_0, 62_0, 44_0, 52_0, 85_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 54_0, 53_0, 67_0, 82_0, 49_0, 63_0, 81_0, 47_0
# [INFO 10-10 23:49:19] ax.service.ax_client: Generated new trial 86 with parameters {'batch_size': 2026, 'train_size': 5000, 'n_epochs': 141, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:49:33] ax.service.ax_client: Completed trial 86 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:49:33] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 84_0, 62_0, 44_0, 52_0, 85_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 54_0, 53_0, 67_0, 82_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:49:40] ax.service.ax_client: Generated new trial 87 with parameters {'batch_size': 2016, 'train_size': 4977, 'n_epochs': 141, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:49:54] ax.service.ax_client: Completed trial 87 with data: {'objective': (0.81, 0.05)}.
# [INFO 10-10 23:49:54] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 84_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 54_0, 53_0, 67_0, 82_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:50:01] ax.service.ax_client: Generated new trial 88 with parameters {'batch_size': 2016, 'train_size': 4908, 'n_epochs': 143, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:50:15] ax.service.ax_client: Completed trial 88 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:50:15] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 84_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:50:22] ax.service.ax_client: Generated new trial 89 with parameters {'batch_size': 2005, 'train_size': 4969, 'n_epochs': 141, 'lr': 0.05, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:50:37] ax.service.ax_client: Completed trial 89 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:50:37] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 84_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:50:44] ax.service.ax_client: Generated new trial 90 with parameters {'batch_size': 2438, 'train_size': 4375, 'n_epochs': 139, 'lr': 0.08, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-10 23:50:56] ax.service.ax_client: Completed trial 90 with data: {'objective': (0.8, 0.07)}.
# [INFO 10-10 23:50:56] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 84_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:51:02] ax.service.ax_client: Generated new trial 91 with parameters {'batch_size': 2001, 'train_size': 5000, 'n_epochs': 136, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:51:16] ax.service.ax_client: Completed trial 91 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-10 23:51:16] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 50_0, 45_0, 79_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:51:23] ax.service.ax_client: Generated new trial 92 with parameters {'batch_size': 1989, 'train_size': 5000, 'n_epochs': 134, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.16}.
# [INFO 10-10 23:51:37] ax.service.ax_client: Completed trial 92 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:51:37] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:51:45] ax.service.ax_client: Generated new trial 93 with parameters {'batch_size': 1303, 'train_size': 2986, 'n_epochs': 161, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.02, 'betas1': 0.0}.
# [INFO 10-10 23:51:56] ax.service.ax_client: Completed trial 93 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:51:56] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:52:04] ax.service.ax_client: Generated new trial 94 with parameters {'batch_size': 1949, 'train_size': 4906, 'n_epochs': 136, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.19}.
# [INFO 10-10 23:52:20] ax.service.ax_client: Completed trial 94 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:52:20] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:52:27] ax.service.ax_client: Generated new trial 95 with parameters {'batch_size': 1915, 'train_size': 4845, 'n_epochs': 136, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.17}.
# [INFO 10-10 23:52:42] ax.service.ax_client: Completed trial 95 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:52:42] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 95_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:52:50] ax.service.ax_client: Generated new trial 96 with parameters {'batch_size': 1918, 'train_size': 4956, 'n_epochs': 134, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:53:05] ax.service.ax_client: Completed trial 96 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:53:05] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 95_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:53:14] ax.service.ax_client: Generated new trial 97 with parameters {'batch_size': 1932, 'train_size': 4865, 'n_epochs': 137, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:53:29] ax.service.ax_client: Completed trial 97 with data: {'objective': (0.79, 0.08)}.
# [INFO 10-10 23:53:29] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 97_0, 95_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:53:37] ax.service.ax_client: Generated new trial 98 with parameters {'batch_size': 1918, 'train_size': 4982, 'n_epochs': 133, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:53:52] ax.service.ax_client: Completed trial 98 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:53:52] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 97_0, 98_0, 95_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:54:01] ax.service.ax_client: Generated new trial 99 with parameters {'batch_size': 1925, 'train_size': 4860, 'n_epochs': 135, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.16}.
# [INFO 10-10 23:54:15] ax.service.ax_client: Completed trial 99 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:54:16] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 97_0, 98_0, 95_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:54:24] ax.service.ax_client: Generated new trial 100 with parameters {'batch_size': 1921, 'train_size': 4858, 'n_epochs': 136, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.19}.
# [INFO 10-10 23:54:39] ax.service.ax_client: Completed trial 100 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:54:39] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 97_0, 98_0, 95_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 47_0, 86_0
# [INFO 10-10 23:54:47] ax.service.ax_client: Generated new trial 101 with parameters {'batch_size': 1929, 'train_size': 4926, 'n_epochs': 134, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.19}.
# [INFO 10-10 23:55:02] ax.service.ax_client: Completed trial 101 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:55:03] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 50_0, 45_0, 79_0, 97_0, 98_0, 95_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 101_0, 47_0, 86_0
# [INFO 10-10 23:55:11] ax.service.ax_client: Generated new trial 102 with parameters {'batch_size': 1910, 'train_size': 4972, 'n_epochs': 133, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:55:26] ax.service.ax_client: Completed trial 102 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:55:26] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 102_0, 50_0, 45_0, 79_0, 97_0, 98_0, 95_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 101_0, 47_0, 86_0
# [INFO 10-10 23:55:34] ax.service.ax_client: Generated new trial 103 with parameters {'batch_size': 1940, 'train_size': 4771, 'n_epochs': 138, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.14}.
# [INFO 10-10 23:55:50] ax.service.ax_client: Completed trial 103 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-10 23:55:50] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 102_0, 50_0, 45_0, 79_0, 97_0, 98_0, 95_0, 103_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 101_0, 47_0, 86_0
# [INFO 10-10 23:55:58] ax.service.ax_client: Generated new trial 104 with parameters {'batch_size': 1901, 'train_size': 5000, 'n_epochs': 133, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:56:14] ax.service.ax_client: Completed trial 104 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-10 23:56:14] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 102_0, 50_0, 104_0, 45_0, 79_0, 97_0, 98_0, 95_0, 103_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 101_0, 47_0, 86_0
# [INFO 10-10 23:56:23] ax.service.ax_client: Generated new trial 105 with parameters {'batch_size': 1925, 'train_size': 4971, 'n_epochs': 134, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:56:37] ax.service.ax_client: Completed trial 105 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:56:38] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 102_0, 50_0, 104_0, 105_0, 45_0, 79_0, 97_0, 98_0, 95_0, 103_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 101_0, 47_0, 86_0
# [INFO 10-10 23:56:46] ax.service.ax_client: Generated new trial 106 with parameters {'batch_size': 1916, 'train_size': 4893, 'n_epochs': 135, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:57:01] ax.service.ax_client: Completed trial 106 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-10 23:57:01] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 102_0, 106_0, 50_0, 104_0, 105_0, 45_0, 79_0, 97_0, 98_0, 95_0, 103_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 101_0, 47_0, 86_0
# [INFO 10-10 23:57:09] ax.service.ax_client: Generated new trial 107 with parameters {'batch_size': 1928, 'train_size': 4937, 'n_epochs': 134, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.19}.
# [INFO 10-10 23:57:24] ax.service.ax_client: Completed trial 107 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-10 23:57:25] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 102_0, 106_0, 50_0, 104_0, 105_0, 45_0, 79_0, 97_0, 98_0, 95_0, 103_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 101_0, 47_0, 86_0
# [INFO 10-10 23:57:33] ax.service.ax_client: Generated new trial 108 with parameters {'batch_size': 1928, 'train_size': 4902, 'n_epochs': 135, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-10 23:57:48] ax.service.ax_client: Completed trial 108 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-10 23:57:48] ModelBridge: Leaving out out-of-design observations for arms: 70_0, 92_0, 102_0, 106_0, 108_0, 50_0, 104_0, 105_0, 45_0, 79_0, 97_0, 98_0, 95_0, 103_0, 48_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 96_0, 80_0, 68_0, 94_0, 78_0, 88_0, 54_0, 53_0, 67_0, 82_0, 89_0, 49_0, 63_0, 81_0, 101_0, 47_0, 86_0
# [INFO 10-10 23:57:57] ax.service.ax_client: Generated new trial 109 with parameters {'batch_size': 1934, 'train_size': 4833, 'n_epochs': 137, 'lr': 0.06, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.18}.
# [INFO 10-10 23:58:12] ax.service.ax_client: Completed trial 109 with data: {'objective': (0.88, 0.0)}.
# ...
# [INFO 10-11 00:13:04] ax.service.ax_client: Completed trial 145 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-11 00:13:04] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 124_0, 70_0, 111_0, 92_0, 102_0, 106_0, 108_0, 134_0, 50_0, 104_0, 133_0, 105_0, 45_0, 143_0, 127_0, 79_0, 142_0, 97_0, 117_0, 98_0, 144_0, 95_0, 112_0, 103_0, 141_0, 48_0, 116_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 118_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 122_0, 96_0, 131_0, 123_0, 80_0, 68_0, 94_0, 78_0, 128_0, 115_0, 139_0, 119_0, 137_0, 88_0, 54_0, 140_0, 121_0, 53_0, 67_0, 135_0, 82_0, 89_0, 49_0, 114_0, 113_0, 120_0, 138_0, 109_0, 63_0, 81_0, 101_0, 110_0, 129_0, 47_0, 86_0
# [INFO 10-11 00:13:13] ax.service.ax_client: Generated new trial 146 with parameters {'batch_size': 2026, 'train_size': 4714, 'n_epochs': 160, 'lr': 0.02, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-11 00:13:31] ax.service.ax_client: Completed trial 146 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-11 00:13:31] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 124_0, 70_0, 111_0, 92_0, 102_0, 106_0, 108_0, 134_0, 50_0, 104_0, 133_0, 105_0, 45_0, 143_0, 127_0, 79_0, 142_0, 146_0, 97_0, 117_0, 98_0, 144_0, 95_0, 112_0, 103_0, 141_0, 48_0, 116_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 118_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 122_0, 96_0, 131_0, 123_0, 80_0, 68_0, 94_0, 78_0, 128_0, 115_0, 139_0, 119_0, 137_0, 88_0, 54_0, 140_0, 121_0, 53_0, 67_0, 135_0, 82_0, 89_0, 49_0, 114_0, 113_0, 120_0, 138_0, 109_0, 63_0, 81_0, 101_0, 110_0, 129_0, 47_0, 86_0
# [INFO 10-11 00:13:39] ax.service.ax_client: Generated new trial 147 with parameters {'batch_size': 1920, 'train_size': 4576, 'n_epochs': 160, 'lr': 0.02, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-11 00:13:56] ax.service.ax_client: Completed trial 147 with data: {'objective': (0.87, 0.01)}.
# [INFO 10-11 00:13:56] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 124_0, 70_0, 111_0, 92_0, 102_0, 106_0, 108_0, 134_0, 50_0, 104_0, 133_0, 105_0, 45_0, 143_0, 127_0, 79_0, 142_0, 146_0, 97_0, 117_0, 98_0, 144_0, 95_0, 112_0, 103_0, 141_0, 48_0, 116_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 118_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 122_0, 96_0, 131_0, 147_0, 123_0, 80_0, 68_0, 94_0, 78_0, 128_0, 115_0, 139_0, 119_0, 137_0, 88_0, 54_0, 140_0, 121_0, 53_0, 67_0, 135_0, 82_0, 89_0, 49_0, 114_0, 113_0, 120_0, 138_0, 109_0, 63_0, 81_0, 101_0, 110_0, 129_0, 47_0, 86_0
# [INFO 10-11 00:14:05] ax.service.ax_client: Generated new trial 148 with parameters {'batch_size': 2018, 'train_size': 4683, 'n_epochs': 160, 'lr': 0.02, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-11 00:14:22] ax.service.ax_client: Completed trial 148 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-11 00:14:22] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 124_0, 70_0, 111_0, 92_0, 102_0, 106_0, 108_0, 134_0, 50_0, 104_0, 133_0, 105_0, 45_0, 143_0, 127_0, 79_0, 142_0, 146_0, 97_0, 117_0, 98_0, 144_0, 95_0, 112_0, 103_0, 141_0, 48_0, 116_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 118_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 122_0, 96_0, 131_0, 147_0, 123_0, 80_0, 68_0, 94_0, 78_0, 128_0, 115_0, 139_0, 119_0, 137_0, 88_0, 148_0, 54_0, 140_0, 121_0, 53_0, 67_0, 135_0, 82_0, 89_0, 49_0, 114_0, 113_0, 120_0, 138_0, 109_0, 63_0, 81_0, 101_0, 110_0, 129_0, 47_0, 86_0
# [INFO 10-11 00:14:31] ax.service.ax_client: Generated new trial 149 with parameters {'batch_size': 2035, 'train_size': 4707, 'n_epochs': 160, 'lr': 0.02, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-11 00:14:47] ax.service.ax_client: Completed trial 149 with data: {'objective': (0.86, 0.0)}.
# [INFO 10-11 00:14:48] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 124_0, 70_0, 111_0, 92_0, 102_0, 106_0, 108_0, 134_0, 50_0, 104_0, 133_0, 105_0, 45_0, 143_0, 127_0, 79_0, 142_0, 146_0, 97_0, 117_0, 98_0, 144_0, 95_0, 112_0, 103_0, 141_0, 48_0, 116_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 118_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 122_0, 96_0, 131_0, 147_0, 123_0, 80_0, 68_0, 94_0, 78_0, 128_0, 115_0, 139_0, 119_0, 137_0, 88_0, 148_0, 54_0, 140_0, 121_0, 53_0, 67_0, 135_0, 82_0, 89_0, 49_0, 114_0, 113_0, 120_0, 138_0, 109_0, 63_0, 81_0, 101_0, 110_0, 129_0, 47_0, 86_0
# [INFO 10-11 00:14:59] ax.service.ax_client: Generated new trial 150 with parameters {'batch_size': 1401, 'train_size': 4601, 'n_epochs': 158, 'lr': 0.04, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.2}.
# [INFO 10-11 00:15:16] ax.service.ax_client: Completed trial 150 with data: {'objective': (0.87, 0.0)}.
# [INFO 10-11 00:15:16] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 124_0, 70_0, 111_0, 92_0, 102_0, 106_0, 108_0, 134_0, 50_0, 104_0, 133_0, 105_0, 45_0, 143_0, 127_0, 79_0, 142_0, 146_0, 97_0, 117_0, 98_0, 144_0, 95_0, 112_0, 103_0, 141_0, 48_0, 116_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 118_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 122_0, 96_0, 131_0, 147_0, 123_0, 80_0, 68_0, 94_0, 78_0, 128_0, 115_0, 139_0, 119_0, 137_0, 88_0, 148_0, 54_0, 140_0, 121_0, 53_0, 67_0, 135_0, 82_0, 89_0, 49_0, 114_0, 113_0, 120_0, 138_0, 109_0, 63_0, 81_0, 101_0, 110_0, 129_0, 47_0, 86_0
# [INFO 10-11 00:15:25] ax.service.ax_client: Generated new trial 151 with parameters {'batch_size': 624, 'train_size': 3983, 'n_epochs': 212, 'lr': 0.01, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.1}.
# [INFO 10-11 00:15:46] ax.service.ax_client: Completed trial 151 with data: {'objective': (0.85, 0.0)}.
# [INFO 10-11 00:15:46] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 124_0, 70_0, 111_0, 92_0, 102_0, 106_0, 108_0, 134_0, 50_0, 104_0, 133_0, 105_0, 45_0, 143_0, 127_0, 79_0, 142_0, 146_0, 97_0, 117_0, 98_0, 144_0, 95_0, 112_0, 103_0, 141_0, 48_0, 116_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 118_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 122_0, 96_0, 131_0, 147_0, 123_0, 80_0, 68_0, 94_0, 78_0, 128_0, 115_0, 139_0, 119_0, 137_0, 88_0, 148_0, 54_0, 140_0, 121_0, 53_0, 67_0, 135_0, 82_0, 89_0, 49_0, 114_0, 113_0, 120_0, 138_0, 109_0, 63_0, 81_0, 101_0, 110_0, 129_0, 47_0, 86_0
# [INFO 10-11 00:15:53] ax.service.ax_client: Generated new trial 152 with parameters {'batch_size': 1549, 'train_size': 4441, 'n_epochs': 176, 'lr': 0.03, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.01}.
# [INFO 10-11 00:16:11] ax.service.ax_client: Completed trial 152 with data: {'objective': (0.86, 0.02)}.
# [INFO 10-11 00:16:11] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 124_0, 70_0, 111_0, 92_0, 102_0, 106_0, 108_0, 134_0, 50_0, 104_0, 133_0, 105_0, 45_0, 143_0, 127_0, 79_0, 142_0, 146_0, 97_0, 117_0, 98_0, 144_0, 95_0, 112_0, 103_0, 141_0, 48_0, 116_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 118_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 122_0, 96_0, 131_0, 147_0, 123_0, 80_0, 68_0, 94_0, 78_0, 128_0, 115_0, 139_0, 119_0, 137_0, 88_0, 148_0, 54_0, 140_0, 121_0, 53_0, 67_0, 135_0, 82_0, 89_0, 49_0, 114_0, 113_0, 120_0, 138_0, 109_0, 63_0, 81_0, 101_0, 110_0, 152_0, 129_0, 47_0, 86_0
# [INFO 10-11 00:16:18] ax.service.ax_client: Generated new trial 153 with parameters {'batch_size': 1541, 'train_size': 4440, 'n_epochs': 176, 'lr': 0.03, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.01}.
# [INFO 10-11 00:16:35] ax.service.ax_client: Completed trial 153 with data: {'objective': (0.88, 0.0)}.
# [INFO 10-11 00:16:36] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 124_0, 70_0, 111_0, 92_0, 102_0, 106_0, 108_0, 134_0, 153_0, 50_0, 104_0, 133_0, 105_0, 45_0, 143_0, 127_0, 79_0, 142_0, 146_0, 97_0, 117_0, 98_0, 144_0, 95_0, 112_0, 103_0, 141_0, 48_0, 116_0, 84_0, 91_0, 62_0, 44_0, 52_0, 85_0, 100_0, 107_0, 118_0, 87_0, 46_0, 69_0, 71_0, 99_0, 42_0, 83_0, 122_0, 96_0, 131_0, 147_0, 123_0, 80_0, 68_0, 94_0, 78_0, 128_0, 115_0, 139_0, 119_0, 137_0, 88_0, 148_0, 54_0, 140_0, 121_0, 53_0, 67_0, 135_0, 82_0, 89_0, 49_0, 114_0, 113_0, 120_0, 138_0, 109_0, 63_0, 81_0, 101_0, 110_0, 152_0, 129_0, 47_0, 86_0
# [INFO 10-11 00:16:42] ax.service.ax_client: Generated new trial 154 with parameters {'batch_size': 1544, 'train_size': 4424, 'n_epochs': 176, 'lr': 0.03, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.01}.
# [INFO 10-11 00:16:59] ax.service.ax_client: Completed trial 154 with data: {'objective': (0.81, 0.06)}.
# [INFO 10-11 00:16:59] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 127_0, 154_0, 142_0, 117_0, 98_0, 144_0, 95_0, 103_0, 116_0, 84_0, 85_0, 96_0, 68_0, 148_0, 137_0, 152_0, 67_0, 138_0, 63_0, 110_0, 129_0, 47_0, 124_0, 111_0, 92_0, 102_0, 108_0, 134_0, 153_0, 104_0, 105_0, 45_0, 146_0, 112_0, 44_0, 52_0, 100_0, 118_0, 71_0, 122_0, 42_0, 83_0, 54_0, 121_0, 89_0, 81_0, 101_0, 86_0, 70_0, 133_0, 79_0, 97_0, 91_0, 69_0, 99_0, 131_0, 147_0, 123_0, 94_0, 53_0, 135_0, 82_0, 141_0, 107_0, 106_0, 50_0, 143_0, 48_0, 62_0, 87_0, 46_0, 80_0, 78_0, 128_0, 115_0, 139_0, 119_0, 88_0, 140_0, 49_0, 114_0, 113_0, 120_0, 109_0
# [INFO 10-11 00:17:08] ax.service.ax_client: Generated new trial 155 with parameters {'batch_size': 1544, 'train_size': 4394, 'n_epochs': 177, 'lr': 0.03, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.01}.
# [INFO 10-11 00:17:25] ax.service.ax_client: Completed trial 155 with data: {'objective': (0.89, 0.01)}.
# [INFO 10-11 00:17:25] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 127_0, 154_0, 142_0, 117_0, 98_0, 144_0, 95_0, 103_0, 116_0, 84_0, 85_0, 96_0, 68_0, 148_0, 137_0, 152_0, 67_0, 138_0, 63_0, 110_0, 129_0, 47_0, 124_0, 111_0, 92_0, 102_0, 108_0, 134_0, 153_0, 104_0, 105_0, 45_0, 146_0, 112_0, 44_0, 52_0, 100_0, 118_0, 71_0, 122_0, 42_0, 83_0, 54_0, 121_0, 89_0, 81_0, 101_0, 86_0, 70_0, 133_0, 79_0, 97_0, 91_0, 69_0, 99_0, 131_0, 147_0, 123_0, 94_0, 53_0, 135_0, 82_0, 141_0, 107_0, 106_0, 50_0, 143_0, 48_0, 62_0, 87_0, 46_0, 80_0, 78_0, 128_0, 115_0, 139_0, 119_0, 88_0, 140_0, 49_0, 114_0, 113_0, 120_0, 109_0
# [INFO 10-11 00:17:32] ax.service.ax_client: Generated new trial 156 with parameters {'batch_size': 1562, 'train_size': 3886, 'n_epochs': 184, 'lr': 0.02, 'weight_decay': 0.0, 'betas0': 0.05, 'betas1': 0.01}.
# [INFO 10-11 00:17:48] ax.service.ax_client: Completed trial 156 with data: {'objective': (0.89, 0.0)}.
# [INFO 10-11 00:17:48] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 127_0, 154_0, 142_0, 117_0, 98_0, 144_0, 95_0, 103_0, 116_0, 84_0, 85_0, 96_0, 68_0, 148_0, 137_0, 152_0, 67_0, 138_0, 63_0, 110_0, 129_0, 47_0, 124_0, 111_0, 92_0, 102_0, 108_0, 134_0, 153_0, 104_0, 105_0, 45_0, 146_0, 112_0, 44_0, 52_0, 100_0, 118_0, 71_0, 122_0, 42_0, 83_0, 54_0, 121_0, 89_0, 81_0, 101_0, 86_0, 70_0, 133_0, 79_0, 97_0, 91_0, 69_0, 99_0, 131_0, 147_0, 123_0, 94_0, 53_0, 135_0, 82_0, 141_0, 107_0, 106_0, 50_0, 143_0, 48_0, 62_0, 87_0, 46_0, 80_0, 78_0, 128_0, 115_0, 139_0, 119_0, 88_0, 140_0, 49_0, 114_0, 113_0, 120_0, 109_0
# [INFO 10-11 00:17:55] ax.service.ax_client: Generated new trial 157 with parameters {'batch_size': 1575, 'train_size': 5000, 'n_epochs': 192, 'lr': 0.03, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.08}.
# [INFO 10-11 00:18:15] ax.service.ax_client: Completed trial 157 with data: {'objective': (0.81, 0.06)}.
# [INFO 10-11 00:18:16] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 127_0, 154_0, 142_0, 117_0, 98_0, 144_0, 95_0, 103_0, 116_0, 84_0, 85_0, 96_0, 68_0, 148_0, 137_0, 152_0, 67_0, 138_0, 63_0, 110_0, 129_0, 47_0, 124_0, 111_0, 92_0, 102_0, 108_0, 134_0, 153_0, 104_0, 105_0, 45_0, 146_0, 112_0, 44_0, 52_0, 100_0, 118_0, 71_0, 122_0, 42_0, 83_0, 54_0, 121_0, 89_0, 81_0, 101_0, 86_0, 70_0, 133_0, 79_0, 97_0, 91_0, 69_0, 99_0, 131_0, 147_0, 123_0, 94_0, 53_0, 135_0, 82_0, 141_0, 107_0, 106_0, 50_0, 143_0, 48_0, 62_0, 87_0, 46_0, 80_0, 78_0, 128_0, 115_0, 139_0, 119_0, 88_0, 140_0, 49_0, 114_0, 113_0, 120_0, 109_0
# [INFO 10-11 00:18:23] ax.service.ax_client: Generated new trial 158 with parameters {'batch_size': 1548, 'train_size': 3607, 'n_epochs': 191, 'lr': 0.02, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-11 00:18:38] ax.service.ax_client: Completed trial 158 with data: {'objective': (0.82, 0.07)}.
# [INFO 10-11 00:18:38] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 127_0, 154_0, 142_0, 117_0, 98_0, 144_0, 95_0, 103_0, 116_0, 84_0, 85_0, 96_0, 68_0, 148_0, 137_0, 152_0, 67_0, 138_0, 63_0, 110_0, 129_0, 47_0, 124_0, 111_0, 92_0, 102_0, 108_0, 134_0, 153_0, 104_0, 105_0, 45_0, 146_0, 112_0, 158_0, 44_0, 52_0, 100_0, 118_0, 71_0, 122_0, 42_0, 83_0, 54_0, 121_0, 89_0, 81_0, 101_0, 86_0, 70_0, 133_0, 79_0, 97_0, 91_0, 69_0, 99_0, 131_0, 147_0, 123_0, 94_0, 53_0, 135_0, 82_0, 141_0, 107_0, 106_0, 50_0, 143_0, 48_0, 62_0, 87_0, 46_0, 80_0, 78_0, 128_0, 115_0, 139_0, 119_0, 88_0, 140_0, 49_0, 114_0, 113_0, 120_0, 109_0
# [INFO 10-11 00:18:45] ax.service.ax_client: Generated new trial 159 with parameters {'batch_size': 1548, 'train_size': 3609, 'n_epochs': 190, 'lr': 0.02, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.0}.
# [INFO 10-11 00:19:00] ax.service.ax_client: Completed trial 159 with data: {'objective': (0.86, 0.01)}.
# [INFO 10-11 00:19:00] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 127_0, 154_0, 142_0, 117_0, 98_0, 144_0, 95_0, 103_0, 116_0, 84_0, 85_0, 96_0, 68_0, 148_0, 137_0, 152_0, 67_0, 138_0, 63_0, 110_0, 129_0, 47_0, 124_0, 111_0, 92_0, 102_0, 108_0, 134_0, 153_0, 104_0, 105_0, 45_0, 146_0, 112_0, 158_0, 44_0, 52_0, 100_0, 118_0, 71_0, 122_0, 42_0, 83_0, 54_0, 121_0, 89_0, 81_0, 101_0, 86_0, 70_0, 133_0, 79_0, 97_0, 91_0, 69_0, 99_0, 131_0, 147_0, 123_0, 94_0, 53_0, 135_0, 82_0, 141_0, 107_0, 106_0, 50_0, 143_0, 48_0, 62_0, 87_0, 46_0, 80_0, 78_0, 128_0, 115_0, 139_0, 119_0, 88_0, 140_0, 49_0, 114_0, 113_0, 120_0, 109_0
# [INFO 10-11 00:19:07] ax.service.ax_client: Generated new trial 160 with parameters {'batch_size': 1687, 'train_size': 5000, 'n_epochs': 137, 'lr': 0.03, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.01}.
# [INFO 10-11 00:19:21] ax.service.ax_client: Completed trial 160 with data: {'objective': (0.88, 0.01)}.
# [INFO 10-11 00:19:21] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 127_0, 154_0, 142_0, 117_0, 98_0, 144_0, 95_0, 103_0, 116_0, 84_0, 85_0, 96_0, 68_0, 148_0, 137_0, 152_0, 67_0, 138_0, 63_0, 110_0, 129_0, 47_0, 124_0, 111_0, 92_0, 102_0, 108_0, 134_0, 153_0, 104_0, 105_0, 45_0, 146_0, 112_0, 158_0, 44_0, 52_0, 100_0, 118_0, 71_0, 122_0, 42_0, 83_0, 54_0, 121_0, 89_0, 81_0, 101_0, 86_0, 70_0, 133_0, 79_0, 97_0, 160_0, 91_0, 69_0, 99_0, 131_0, 147_0, 123_0, 94_0, 53_0, 135_0, 82_0, 141_0, 107_0, 106_0, 50_0, 143_0, 48_0, 62_0, 87_0, 46_0, 80_0, 78_0, 128_0, 115_0, 139_0, 119_0, 88_0, 140_0, 49_0, 114_0, 113_0, 120_0, 109_0
# [INFO 10-11 00:19:28] ax.service.ax_client: Generated new trial 161 with parameters {'batch_size': 1665, 'train_size': 5000, 'n_epochs': 136, 'lr': 0.03, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.01}.
# [INFO 10-11 00:19:42] ax.service.ax_client: Completed trial 161 with data: {'objective': (0.8, 0.03)}.
# [INFO 10-11 00:19:43] ModelBridge: Leaving out out-of-design observations for arms: 132_0, 127_0, 154_0, 142_0, 117_0, 98_0, 144_0, 95_0, 103_0, 116_0, 84_0, 85_0, 96_0, 68_0, 148_0, 137_0, 152_0, 67_0, 138_0, 63_0, 110_0, 129_0, 47_0, 124_0, 111_0, 92_0, 102_0, 108_0, 134_0, 153_0, 104_0, 105_0, 45_0, 146_0, 112_0, 158_0, 44_0, 52_0, 100_0, 118_0, 71_0, 122_0, 42_0, 83_0, 54_0, 121_0, 89_0, 81_0, 101_0, 86_0, 70_0, 133_0, 79_0, 97_0, 160_0, 91_0, 69_0, 99_0, 131_0, 147_0, 123_0, 94_0, 53_0, 135_0, 82_0, 141_0, 107_0, 106_0, 50_0, 143_0, 48_0, 62_0, 87_0, 46_0, 80_0, 78_0, 128_0, 115_0, 139_0, 119_0, 88_0, 140_0, 49_0, 114_0, 113_0, 120_0, 109_0
# [INFO 10-11 00:19:51] ax.service.ax_client: Generated new trial 162 with parameters {'batch_size': 2637, 'train_size': 5000, 'n_epochs': 146, 'lr': 0.13, 'weight_decay': 0.0, 'betas0': 0.2, 'betas1': 0.06}.

# %%
 i = 0

# %%
train.__file__
# Out:
# '/content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/3x3/train.py'

# %%
open(f"/content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/colab/hyperparameters_{run_mode}.pl", "wb")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-a68ed25944c5> in <module>()
# ----> 1 open(f"/content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/colab/hyperparameters_{run_mode}.pl", "wb")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/colab/hyperparameters_unfrozen_convolution_relu.pl'

# %%
open(f"/content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/hyperparameters_{run_mode}.pl", "wb")
# Out:
# <_io.BufferedWriter name='/content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/hyperparameters_unfrozen_convolution_relu.pl'>

# %%
with open(f"/content/drive/My Drive/Year 4: Synthesis/NS162: Statistical Mechanics/Renormalization Research Project/renormalization/supervised_convnet/t_2.269/hyperparameters_{run_mode}.pl", "wb") as handle:
    pickle.dump(hyper, handle, protocol = pickle.HIGHEST_PROTOCOL)

# %%
# !ls /content/drive/My\ Drive/Year\ 4:\ Synthesis/NS162:\ Statistical\ Mechanics/Renormalization\ Research\ Project/renormalization/supervised_convnet/t_2.269/
# Out:
#  3x3	        generate_uncorrelated_data.py		       runs
#  81x81	        hyperparameters_unfrozen_convolution_relu.pl
# '9x9->3x3.pt'   ising81x81_temp2.269.npy

# %%
i = 0
