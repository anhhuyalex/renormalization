# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


import torch
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np

import importlib
import utils
import glob
from collections import defaultdict

import seaborn as sns
import pandas as pd
import os
import math

# %%
importlib.reload(utils)
workdir = "/scratch/gpfs/qanguyen" 
_ = utils.shuffled_pca_regression(   
    outdir = f"{workdir}/imagenet_info",
    hue_variable = "block_size",
    exp_name = "sklearnlbfgs_shuffledregression_highsignal_mnist_noinversetransform_zeroinit_JUN5_wd_1.0*",
    num_runs_to_analyze = 30000
)
# Out:
# P None num runs 529

# %%
importlib.reload(utils)
workdir = "/scratch/gpfs/qanguyen" 
_ = utils.shuffled_pca_regression(   
    outdir = f"{workdir}/imagenet_info",
    hue_variable = "block_size",
    exp_name = "sklearnlbfgs_shuffledregression_highsignal_mnist_noinversetransform_zeroinit_JUN5_wd_1e-2*",
    num_runs_to_analyze = 30000
)
# Out:
# P None num runs 76
